# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import preprocessing

fname = ['/Users/bytedance/Desktop/AI/data/student/student-mat.csv', 'data/student/student-por.csv']
data = pd.read_csv('/Users/bytedance/Desktop/AI/data/student/student-mat.csv', sep=';')

numerical_feature = ["age","Medu","Fedu","traveltime", "studytime", "failures", "famrel", "freetime", "goout", "Dalc", "Walc", "health","absences","G1","G2"]

# data = data.apply(preprocessing.LabelEncoder().fit_transform)
data = data.drop(numerical_feature,axis = 1)
data = data.apply(preprocessing.LabelEncoder().fit_transform)

mask = np.zeros_like(data.corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Math Pearson Correlation Matrix',fontsize=25)

sns.heatmap(data.corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9})

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn import preprocessing

fname = ['/Users/bytedance/Desktop/AI/data/student/student-mat.csv', 'data/student/student-por.csv']
data = pd.read_csv('/Users/bytedance/Desktop/AI/data/student/student-por.csv', sep=';')

numerical_feature = ["age","Medu","Fedu","traveltime", "studytime", "failures", "famrel", "freetime", "goout", "Dalc", "Walc", "health","absences","G1","G2"]

# data = data.apply(preprocessing.LabelEncoder().fit_transform)
data = data.drop(numerical_feature,axis = 1)
data = data.apply(preprocessing.LabelEncoder().fit_transform)

mask = np.zeros_like(data.corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Por Pearson Correlation Matrix',fontsize=25)

sns.heatmap(data.corr(),linewidths=0.25,vmax=0.7,square=True,cmap="BuGn", #"BuGn_r" to reverse 
            linecolor='w',annot=True,annot_kws={"size":8},mask=mask,cbar_kws={"shrink": .9})

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

data = pd.read_csv('/Users/bytedance/Desktop/AI/data/student/student-mat.csv', sep=';')

f, axes = plt.subplots(6, 3, figsize=(20, 20))
f.suptitle('math', fontsize = 20)
# total 14 binary feature
sns.scatterplot(x = data['school'], y = data['G3'],ax=axes[0, 0])
sns.scatterplot(x = data['sex'], y = data['G3'],ax=axes[0, 1])
sns.scatterplot(x = data['address'], y = data['G3'],ax=axes[0, 2])

sns.scatterplot(x = data['famsize'], y = data['G3'],ax=axes[1, 0])
sns.scatterplot(x = data['Pstatus'], y = data['G3'],ax=axes[1, 1])
sns.scatterplot(x = data['schoolsup'], y = data['G3'],ax=axes[1, 2])

sns.scatterplot(x = data['famsup'], y = data['G3'],ax=axes[2, 0])
sns.scatterplot(x = data['paid'], y = data['G3'],ax=axes[2, 1])
sns.scatterplot(x = data['activities'], y = data['G3'],ax=axes[2, 2])

sns.scatterplot(x = data['nursery'], y = data['G3'],ax=axes[3, 0])
sns.scatterplot(x = data['higher'], y = data['G3'],ax=axes[3, 1])
sns.scatterplot(x = data['internet'], y = data['G3'],ax=axes[3, 2])

sns.scatterplot(x = data['romantic'], y = data['G3'],ax=axes[4, 0])
sns.scatterplot(x = data['reason'], y = data['G3'],ax=axes[4, 1])
sns.scatterplot(x = data['guardian'], y = data['G3'],ax=axes[4, 2])

sns.scatterplot(x = data['Fjob'], y = data['G3'],ax=axes[5,0])

sns.scatterplot(x = data['Mjob'], y = data['G3'],ax=axes[5,1])

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

data = pd.read_csv('/Users/bytedance/Desktop/AI/data/student/student-por.csv', sep=';')

f, axes = plt.subplots(6, 3, figsize=(20, 20))
f.suptitle('por', fontsize = 20)
# total 14 binary feature
sns.scatterplot(x = data['school'], y = data['G3'],ax=axes[0, 0])
sns.scatterplot(x = data['sex'], y = data['G3'],ax=axes[0, 1])
sns.scatterplot(x = data['address'], y = data['G3'],ax=axes[0, 2])

sns.scatterplot(x = data['famsize'], y = data['G3'],ax=axes[1, 0])
sns.scatterplot(x = data['Pstatus'], y = data['G3'],ax=axes[1, 1])
sns.scatterplot(x = data['schoolsup'], y = data['G3'],ax=axes[1, 2])

sns.scatterplot(x = data['famsup'], y = data['G3'],ax=axes[2, 0])
sns.scatterplot(x = data['paid'], y = data['G3'],ax=axes[2, 1])
sns.scatterplot(x = data['activities'], y = data['G3'],ax=axes[2, 2])

sns.scatterplot(x = data['nursery'], y = data['G3'],ax=axes[3, 0])
sns.scatterplot(x = data['higher'], y = data['G3'],ax=axes[3, 1])
sns.scatterplot(x = data['internet'], y = data['G3'],ax=axes[3, 2])

sns.scatterplot(x = data['romantic'], y = data['G3'],ax=axes[4, 0])
sns.scatterplot(x = data['reason'], y = data['G3'],ax=axes[4, 1])
sns.scatterplot(x = data['guardian'], y = data['G3'],ax=axes[4, 2])

sns.scatterplot(x = data['Fjob'], y = data['G3'],ax=axes[5,0])

sns.scatterplot(x = data['Mjob'], y = data['G3'],ax=axes[5,1])

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
a = [0.4463915, 0.1715549, 0.09477074, 0.07867165 ,0.05679156, 0.03922934,
 0.03430982, 0.02195397, 0.0174122,  0.01577113, 0.01213624, 0.00726717,
 0.00373979]
x = np.arange(1,14)
ax = sns.barplot(x=x,y=a)
ax.set_ylabel("Percentage")
ax.set_xlabel("Eigen value index")
# Out:
# Text(0, 0.5, 'percentage')
